# %%
from matplotlib import image, pyplot
from scipy import ndimage

# %%
img = image.imread(r"C:\users\lolla srikanth\Pictures\New folder (3)\Screenshots\Screenshot 2024-09-29 211140.png")

# %%
pyplot.imshow(img)

# %%
rotate_rob = ndimage.rotate(img,120,mode='constant')

# %%
pyplot.imshow(rotate_rob)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.3295276..1.3777713].
